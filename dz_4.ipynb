# %%
# Task 1
print("Task 1")
def foo1(*nums):
    sum = 0
    for n in nums:
        sum += n
    if(nums):
        print("Срзнач:",sum / len(nums))

foo1(1, 2, 3, 4, 5)
foo1(5, 2, 1, -2, -3)
foo1(5)
foo1()

# Task 2
print("\nTask 2")
def foo2(**data):
    for key, val in data.items():
        print("key={} value={}\n".format(key, val))

foo2(name="Даня", status = "Красавчик" )

# Task 3
print("\nTask 3")
def foo3(num):
    try:
        print(1/num)
    except Exception as e:
        print("Ошибка: " + str(e))
    else:
        print("сработало else")
    finally: 
        print("Сработало finally\n")
#else  срабатывает только, есл ошибка не происходит, а finally срабатывает всегда
foo3(0)
foo3(5)
# Task 4
print("\nTask 4")
def foo4(nums,k):
    for i in range(k):
        nums.insert(0,nums[len(nums)-1])
        del nums[len(nums)-1]
    return nums

args=[1,2,3,4,5,6,7]
print(foo4(args,3),"\n")
args=[1,2,3,4,5,6,7]
print(foo4(args,0),"\n")
args=[1]
print(foo4(args,2),"\n")
args=[1,2,3,4,5,6,7]
print(foo4(args,9),"\n")
# Task 5
print("\nTask 5")

def foo5(nums):
    i=0
    k = len(nums) - 1
    while i < k:
        if nums[i] == 0:
            del nums[i]
            nums.insert(len(nums),0)
            k-=1
        else:
            i+=1
    print (nums)

foo5([0,1,2,0,0,6,7,0])
foo5([0])
foo5([2])
# Out:
# Task 1
# Срзнач: 3.0
# Срзнач: 0.6
# Срзнач: 5.0
#
# Task 2
# key=name value=Даня
#
# key=status value=Красавчик
#
#
# Task 3
# Ошибка: division by zero
# Сработало finally
#
# 0.2
# сработало else
# Сработало finally
#
#
# Task 4
# [5, 6, 7, 1, 2, 3, 4]
#
# [1, 2, 3, 4, 5, 6, 7]
#
# [1]
#
# [6, 7, 1, 2, 3, 4, 5]
#
#
# Task 5
# [1, 2, 6, 7, 0, 0, 0, 0]
# [0]
# [2]
